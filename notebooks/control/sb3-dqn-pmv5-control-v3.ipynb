# %%
# %%capture
# !pip install stable-baselines3[extra]
# !pip install moviepy

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback, CallbackList
from stable_baselines3.common.logger import TensorBoardOutputFormat, Video
from stable_baselines3.common.evaluation import evaluate_policy

from typing import Any, Dict

import gymnasium as gym
import torch as th
import numpy as np

EVAL_CALLBACK_FREQ = 50_000
VIDEO_CALLBACK_FREQ = 250_000
FRAMESKIP = 4
NUM_TIMESTEPS = 1_000_000
# Out:
# 2024-05-01 16:40:49.228128: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-01 16:40:49.228225: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-01 16:40:49.464967: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
class VideoRecorderCallback(BaseCallback):
    def __init__(self, eval_env: gym.Env, render_freq: int, n_eval_episodes: int = 1, deterministic: bool = True):
        """
        Records a video of an agent's trajectory traversing ``eval_env`` and logs it to TensorBoard

        :param eval_env: A gym environment from which the trajectory is recorded
        :param render_freq: Render the agent's trajectory every eval_freq call of the callback.
        :param n_eval_episodes: Number of episodes to render
        :param deterministic: Whether to use deterministic or stochastic policy
        """
        super().__init__()
        self._eval_env = eval_env
        self._render_freq = render_freq
        self._n_eval_episodes = n_eval_episodes
        self._deterministic = deterministic

    def _on_step(self) -> bool:
        if self.n_calls % self._render_freq == 0:
            screens = []

            def grab_screens(_locals: Dict[str, Any], _globals: Dict[str, Any]) -> None:
                """
                Renders the environment in its current state, recording the screen in the captured `screens` list

                :param _locals: A dictionary containing all local variables of the callback's scope
                :param _globals: A dictionary containing all global variables of the callback's scope
                """
                screen = self._eval_env.render()
                # PyTorch uses CxHxW vs HxWxC gym (and tensorflow) image convention
                screens.append(screen.transpose(2, 0, 1))

            evaluate_policy(
                self.model,
                self._eval_env,
                callback=grab_screens,
                n_eval_episodes=self._n_eval_episodes,
                deterministic=self._deterministic,
            )
            # Convert screens to a numpy array before passing to pytorch
            screens_array = np.array(screens)
            self.logger.record(
                "trajectory/video",
                Video(th.ByteTensor([screens_array]), fps=60),
                exclude=("stdout", "log", "json", "csv"),
            )
        return True

# %%
eval_env = Monitor(gym.make("ALE/Pacman-v5", render_mode="rgb_array", frameskip=FRAMESKIP))
train_env = gym.make("ALE/Pacman-v5", render_mode="rgb_array", frameskip=FRAMESKIP)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %%
eval_callback = EvalCallback(eval_env, log_path="./", eval_freq=EVAL_CALLBACK_FREQ, n_eval_episodes=5, deterministic=True, render=False)
video_callback = VideoRecorderCallback(eval_env, render_freq=VIDEO_CALLBACK_FREQ)
callback_list = CallbackList([eval_callback, video_callback])

# %%
model = DQN(
    "CnnPolicy",
    train_env,
    verbose=1,
    buffer_size=100_000,
    tensorboard_log="./")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=NUM_TIMESTEPS, callback=callback_list, tb_log_name="./control/")
# Out:
# Logging to ././control/_1
# /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/callbacks.py:403: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7cef062c3ca0> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7cef061a5780>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 419      |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 674      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 409      |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 686      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 691      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5162     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 688      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 6722     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 417      |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 689      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 8346     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 686      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 10148    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 418      |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 687      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 11704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 688      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 13458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 687      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 14888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 686      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 16551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 687      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 18235    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 416      |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 688      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 19947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 416      |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 689      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 21655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 689      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 23191    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 690      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 24857    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 415      |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.748    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 690      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 26547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 690      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 28125    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 690      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 29785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 413      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 690      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 31373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 413      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 691      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 33065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 415      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 691      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 34839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 415      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 691      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 36477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 416      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.636    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 691      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 38299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 417      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 692      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 40079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 417      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 692      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 41725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 692      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 44003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 693      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 45559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 422      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 693      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 47359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 693      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 49043    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=2.00 +/- 0.00
# Episode length: 362.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 362      |
# |    mean_reward      | 2        |
# | rollout/            |          |
# |    exploration_rate | 0.525    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 428      |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 602      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 51173    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0447   |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.494    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 554      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 53243    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00138  |
# |    n_updates        | 810      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 523      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 54853    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000531 |
# |    n_updates        | 1213     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 491      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 56833    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 1708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 440      |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 465      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 58863    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000601 |
# |    n_updates        | 2215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.417    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 436      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 61415    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000856 |
# |    n_updates        | 2853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 421      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 62963    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00566  |
# |    n_updates        | 3240     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.383    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 404      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 64981    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 3745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 458      |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 386      |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 67431    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 4357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 374      |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 69283    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 4820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 365      |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 70873    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 5218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 355      |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 72799    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00678  |
# |    n_updates        | 5699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 346      |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 74521    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00768  |
# |    n_updates        | 6130     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 339      |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 76167    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 6541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 471      |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 330      |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 78475    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00865  |
# |    n_updates        | 7118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 472      |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 323      |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 80238    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 7559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 472      |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.221    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 317      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 82035    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 8008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 474      |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.203    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 311      |
# |    time_elapsed     | 269      |
# |    total_timesteps  | 83845    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 8461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 477      |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 304      |
# |    time_elapsed     | 281      |
# |    total_timesteps  | 85956    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00902  |
# |    n_updates        | 8988     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 483      |
# |    ep_rew_mean      | 25.5     |
# |    exploration_rate | 0.16     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 298      |
# |    time_elapsed     | 296      |
# |    total_timesteps  | 88413    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00534  |
# |    n_updates        | 9603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 492      |
# |    ep_rew_mean      | 26.7     |
# |    exploration_rate | 0.136    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 291      |
# |    time_elapsed     | 312      |
# |    total_timesteps  | 90955    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0563   |
# |    n_updates        | 10238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 494      |
# |    ep_rew_mean      | 26.7     |
# |    exploration_rate | 0.113    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 285      |
# |    time_elapsed     | 326      |
# |    total_timesteps  | 93397    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0032   |
# |    n_updates        | 10849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.0954   |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 281      |
# |    time_elapsed     | 337      |
# |    total_timesteps  | 95219    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 11304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.0777   |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 277      |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 97085    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 11771    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 27.8     |
# |    exploration_rate | 0.0587   |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 273      |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 99079    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0357   |
# |    n_updates        | 12269    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=25.00 +/- 12.66
# Episode length: 533.60 +/- 173.11
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 534      |
# |    mean_reward      | 25       |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 100000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00724  |
# |    n_updates        | 12499    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 498      |
# |    ep_rew_mean      | 27.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 265      |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 101011   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 12752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 502      |
# |    ep_rew_mean      | 28.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 262      |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 103484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 13370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 504      |
# |    ep_rew_mean      | 28.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 259      |
# |    time_elapsed     | 405      |
# |    total_timesteps  | 105228   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 13806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 505      |
# |    ep_rew_mean      | 28.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 256      |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 107330   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 14332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 502      |
# |    ep_rew_mean      | 28.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 254      |
# |    time_elapsed     | 428      |
# |    total_timesteps  | 109112   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 14777    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 496      |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 252      |
# |    time_elapsed     | 440      |
# |    total_timesteps  | 110972   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0095   |
# |    n_updates        | 15242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 250      |
# |    time_elapsed     | 450      |
# |    total_timesteps  | 112642   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00561  |
# |    n_updates        | 15660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 27.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 247      |
# |    time_elapsed     | 464      |
# |    total_timesteps  | 114966   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0386   |
# |    n_updates        | 16241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 28.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 245      |
# |    time_elapsed     | 477      |
# |    total_timesteps  | 117134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.006    |
# |    n_updates        | 16783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 502      |
# |    ep_rew_mean      | 28.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 243      |
# |    time_elapsed     | 491      |
# |    total_timesteps  | 119520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 17379    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 507      |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 241      |
# |    time_elapsed     | 503      |
# |    total_timesteps  | 121540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0669   |
# |    n_updates        | 17884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 511      |
# |    ep_rew_mean      | 30.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 239      |
# |    time_elapsed     | 518      |
# |    total_timesteps  | 123932   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 18482    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 514      |
# |    ep_rew_mean      | 30.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 237      |
# |    time_elapsed     | 529      |
# |    total_timesteps  | 125872   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 18967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 519      |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 235      |
# |    time_elapsed     | 543      |
# |    total_timesteps  | 128022   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0369   |
# |    n_updates        | 19505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 518      |
# |    ep_rew_mean      | 30.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 234      |
# |    time_elapsed     | 556      |
# |    total_timesteps  | 130272   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 20067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 519      |
# |    ep_rew_mean      | 30.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 232      |
# |    time_elapsed     | 567      |
# |    total_timesteps  | 132172   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 20542    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 520      |
# |    ep_rew_mean      | 31.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 231      |
# |    time_elapsed     | 579      |
# |    total_timesteps  | 134064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 21015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 529      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 229      |
# |    time_elapsed     | 595      |
# |    total_timesteps  | 136756   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 21688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 532      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 228      |
# |    time_elapsed     | 610      |
# |    total_timesteps  | 139180   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 22294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 529      |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 226      |
# |    time_elapsed     | 623      |
# |    total_timesteps  | 141312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 22827    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 527      |
# |    ep_rew_mean      | 32.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 225      |
# |    time_elapsed     | 637      |
# |    total_timesteps  | 143658   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 23414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 527      |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 224      |
# |    time_elapsed     | 652      |
# |    total_timesteps  | 146132   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0073   |
# |    n_updates        | 24032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 528      |
# |    ep_rew_mean      | 33.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 223      |
# |    time_elapsed     | 663      |
# |    total_timesteps  | 148052   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 24512    |
# ----------------------------------
# Eval num_timesteps=150000, episode_reward=32.80 +/- 4.35
# Episode length: 540.80 +/- 39.43
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 541      |
# |    mean_reward      | 32.8     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 150000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 24999    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 536      |
# |    ep_rew_mean      | 35.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 219      |
# |    time_elapsed     | 685      |
# |    total_timesteps  | 150672   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0814   |
# |    n_updates        | 25167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 539      |
# |    ep_rew_mean      | 35.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 218      |
# |    time_elapsed     | 699      |
# |    total_timesteps  | 152938   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0329   |
# |    n_updates        | 25734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 550      |
# |    ep_rew_mean      | 36.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 217      |
# |    time_elapsed     | 718      |
# |    total_timesteps  | 156046   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00754  |
# |    n_updates        | 26511    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 553      |
# |    ep_rew_mean      | 37.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 216      |
# |    time_elapsed     | 735      |
# |    total_timesteps  | 158812   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 27202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 562      |
# |    ep_rew_mean      | 37.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 214      |
# |    time_elapsed     | 750      |
# |    total_timesteps  | 161434   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00955  |
# |    n_updates        | 27858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 563      |
# |    ep_rew_mean      | 38       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 214      |
# |    time_elapsed     | 764      |
# |    total_timesteps  | 163652   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0238   |
# |    n_updates        | 28412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 572      |
# |    ep_rew_mean      | 38.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 213      |
# |    time_elapsed     | 780      |
# |    total_timesteps  | 166298   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 29074    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 578      |
# |    ep_rew_mean      | 40.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 212      |
# |    time_elapsed     | 795      |
# |    total_timesteps  | 168780   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00853  |
# |    n_updates        | 29694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 585      |
# |    ep_rew_mean      | 40.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 211      |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 171162   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0363   |
# |    n_updates        | 30290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 585      |
# |    ep_rew_mean      | 40.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 210      |
# |    time_elapsed     | 823      |
# |    total_timesteps  | 173420   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 30854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 591      |
# |    ep_rew_mean      | 41.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 209      |
# |    time_elapsed     | 839      |
# |    total_timesteps  | 176238   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 31559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 593      |
# |    ep_rew_mean      | 41.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 209      |
# |    time_elapsed     | 855      |
# |    total_timesteps  | 178775   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 32193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 594      |
# |    ep_rew_mean      | 42.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 208      |
# |    time_elapsed     | 867      |
# |    total_timesteps  | 180895   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0653   |
# |    n_updates        | 32723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 590      |
# |    ep_rew_mean      | 42.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 207      |
# |    time_elapsed     | 880      |
# |    total_timesteps  | 182891   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 33222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 593      |
# |    ep_rew_mean      | 42.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 207      |
# |    time_elapsed     | 893      |
# |    total_timesteps  | 185203   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 33800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 596      |
# |    ep_rew_mean      | 43.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 206      |
# |    time_elapsed     | 908      |
# |    total_timesteps  | 187653   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.039    |
# |    n_updates        | 34413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 600      |
# |    ep_rew_mean      | 46.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 205      |
# |    time_elapsed     | 924      |
# |    total_timesteps  | 190267   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 35066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 610      |
# |    ep_rew_mean      | 47.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 205      |
# |    time_elapsed     | 941      |
# |    total_timesteps  | 193185   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 35796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 614      |
# |    ep_rew_mean      | 48.4     |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 212888   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 815      |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1296     |
# |    fps              | 162      |
# |    time_elapsed     | 5553     |
# |    total_timesteps  | 904178   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.264    |
# |    n_updates        | 213544   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 819      |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 162      |
# |    time_elapsed     | 5575     |
# |    total_timesteps  | 907768   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0572   |
# |    n_updates        | 214441   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 821      |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1304     |
# |    fps              | 162      |
# |    time_elapsed     | 5597     |
# |    total_timesteps  | 911383   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0388   |
# |    n_updates        | 215345   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 822      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1308     |
# |    fps              | 162      |
# |    time_elapsed     | 5615     |
# |    total_timesteps  | 914382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0438   |
# |    n_updates        | 216095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 825      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1312     |
# |    fps              | 162      |
# |    time_elapsed     | 5637     |
# |    total_timesteps  | 918015   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0364   |
# |    n_updates        | 217003   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 823      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1316     |
# |    fps              | 162      |
# |    time_elapsed     | 5656     |
# |    total_timesteps  | 921109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.163    |
# |    n_updates        | 217777   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 834      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 162      |
# |    time_elapsed     | 5679     |
# |    total_timesteps  | 925041   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 218760   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 839      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1324     |
# |    fps              | 162      |
# |    time_elapsed     | 5705     |
# |    total_timesteps  | 929273   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.494    |
# |    n_updates        | 219818   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 839      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1328     |
# |    fps              | 162      |
# |    time_elapsed     | 5724     |
# |    total_timesteps  | 932399   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0434   |
# |    n_updates        | 220599   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 837      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1332     |
# |    fps              | 162      |
# |    time_elapsed     | 5744     |
# |    total_timesteps  | 935803   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 221450   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 840      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1336     |
# |    fps              | 162      |
# |    time_elapsed     | 5765     |
# |    total_timesteps  | 939231   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.21     |
# |    n_updates        | 222307   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 841      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 162      |
# |    time_elapsed     | 5786     |
# |    total_timesteps  | 942649   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 223162   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 843      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1344     |
# |    fps              | 162      |
# |    time_elapsed     | 5807     |
# |    total_timesteps  | 946151   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 224037   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 847      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1348     |
# |    fps              | 162      |
# |    time_elapsed     | 5827     |
# |    total_timesteps  | 949539   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 224884   |
# ----------------------------------
# Eval num_timesteps=950000, episode_reward=103.60 +/- 3.77
# Episode length: 903.00 +/- 57.41
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 903      |
# |    mean_reward      | 104      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 950000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0451   |
# |    n_updates        | 224999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 848      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1352     |
# |    fps              | 162      |
# |    time_elapsed     | 5858     |
# |    total_timesteps  | 952912   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34     |
# |    n_updates        | 225727   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 851      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1356     |
# |    fps              | 162      |
# |    time_elapsed     | 5881     |
# |    total_timesteps  | 956616   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.255    |
# |    n_updates        | 226653   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 853      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 162      |
# |    time_elapsed     | 5902     |
# |    total_timesteps  | 960014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0487   |
# |    n_updates        | 227503   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 858      |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1364     |
# |    fps              | 162      |
# |    time_elapsed     | 5925     |
# |    total_timesteps  | 963830   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.501    |
# |    n_updates        | 228457   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 859      |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1368     |
# |    fps              | 162      |
# |    time_elapsed     | 5945     |
# |    total_timesteps  | 967164   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 229290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 854      |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1372     |
# |    fps              | 162      |
# |    time_elapsed     | 5963     |
# |    total_timesteps  | 970056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0625   |
# |    n_updates        | 230013   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 859      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 162      |
# |    time_elapsed     | 5986     |
# |    total_timesteps  | 973880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.329    |
# |    n_updates        | 230969   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 856      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 162      |
# |    time_elapsed     | 6005     |
# |    total_timesteps  | 977042   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 231760   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 853      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 162      |
# |    time_elapsed     | 6026     |
# |    total_timesteps  | 980516   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.27     |
# |    n_updates        | 232628   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 855      |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 162      |
# |    time_elapsed     | 6048     |
# |    total_timesteps  | 984266   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0447   |
# |    n_updates        | 233566   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 866      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 162      |
# |    time_elapsed     | 6072     |
# |    total_timesteps  | 988133   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 234533   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 874      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 162      |
# |    time_elapsed     | 6093     |
# |    total_timesteps  | 991607   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 235401   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 870      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 162      |
# |    time_elapsed     | 6112     |
# |    total_timesteps  | 994795   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.266    |
# |    n_updates        | 236198   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 864      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 162      |
# |    time_elapsed     | 6130     |
# |    total_timesteps  | 997779   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 236944   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=112.20 +/- 9.68
# Episode length: 981.60 +/- 73.91
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 982      |
# |    mean_reward      | 112      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 237499   |
# ----------------------------------

# %%
model.save("ALE-Pacman-v5-control-v3")

# %%
# %%capture
# !pip install stable-baselines3[extra]
# !pip install moviepy

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback, CallbackList
from stable_baselines3.common.logger import TensorBoardOutputFormat, Video
from stable_baselines3.common.evaluation import evaluate_policy

from typing import Any, Dict

import gymnasium as gym
import torch as th
import numpy as np

EVAL_CALLBACK_FREQ = 50_000
VIDEO_CALLBACK_FREQ = 200_000
FRAMESKIP = 4
NUM_TIMESTEPS = 1_000_000
# Out:
# 2024-05-02 14:34:30.363062: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 14:34:30.363200: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 14:34:30.466849: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
class VideoRecorderCallback(BaseCallback):
    def __init__(self, eval_env: gym.Env, render_freq: int, n_eval_episodes: int = 1, deterministic: bool = True):
        """
        Records a video of an agent's trajectory traversing ``eval_env`` and logs it to TensorBoard

        :param eval_env: A gym environment from which the trajectory is recorded
        :param render_freq: Render the agent's trajectory every eval_freq call of the callback.
        :param n_eval_episodes: Number of episodes to render
        :param deterministic: Whether to use deterministic or stochastic policy
        """
        super().__init__()
        self._eval_env = eval_env
        self._render_freq = render_freq
        self._n_eval_episodes = n_eval_episodes
        self._deterministic = deterministic

    def _on_step(self) -> bool:
        if self.n_calls % self._render_freq == 0:
            screens = []

            def grab_screens(_locals: Dict[str, Any], _globals: Dict[str, Any]) -> None:
                """
                Renders the environment in its current state, recording the screen in the captured `screens` list

                :param _locals: A dictionary containing all local variables of the callback's scope
                :param _globals: A dictionary containing all global variables of the callback's scope
                """
                screen = self._eval_env.render()
                # PyTorch uses CxHxW vs HxWxC gym (and tensorflow) image convention
                screens.append(screen.transpose(2, 0, 1))

            evaluate_policy(
                self.model,
                self._eval_env,
                callback=grab_screens,
                n_eval_episodes=self._n_eval_episodes,
                deterministic=self._deterministic,
            )
            # Convert screens to a numpy array before passing to pytorch
            screens_array = np.array(screens)
            self.logger.record(
                "trajectory/video",
                Video(th.ByteTensor([screens_array]), fps=60),
                exclude=("stdout", "log", "json", "csv"),
            )
        return True

# %%
eval_env = Monitor(gym.make("ALE/Pacman-v5", render_mode="rgb_array", frameskip=FRAMESKIP))
train_env = gym.make("ALE/Pacman-v5", render_mode="rgb_array", frameskip=FRAMESKIP)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %%
eval_callback = EvalCallback(eval_env, log_path="./", eval_freq=EVAL_CALLBACK_FREQ, n_eval_episodes=5, deterministic=True, render=False)
video_callback = VideoRecorderCallback(eval_env, render_freq=VIDEO_CALLBACK_FREQ)
callback_list = CallbackList([eval_callback, video_callback])

# %%
model = DQN(
    "CnnPolicy",
    train_env,
    verbose=1,
    buffer_size=100_000,
    exploration_fraction = 0.3,
    tensorboard_log="./")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=NUM_TIMESTEPS, callback=callback_list, tb_log_name="./control/")
# Out:
# Logging to ././control/_1
# /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/callbacks.py:403: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7b39bde327d0> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7b389d779990>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 621      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 400      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 632      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 3196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 407      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 632      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 4880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 400      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 635      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 404      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 636      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 8086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 638      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 9948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 418      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 638      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 11704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 640      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 13474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 428      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 642      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 15398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 641      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 17200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 643      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 644      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 20716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 644      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 22424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 644      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 24378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 645      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 26692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 440      |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 645      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 28144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 645      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 30092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 439      |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 644      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 31624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 644      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 33216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 644      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 35030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 644      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 36804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 644      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 38424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 645      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 40036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 645      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 41672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 645      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 43180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 644      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 44810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 644      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 46360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 644      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 47868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 644      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 49432    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=1.00 +/- 0.00
# Episode length: 420.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 420      |
# |    mean_reward      | 1        |
# | rollout/            |          |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 570      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 51176    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000534 |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 540      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 53010    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000761 |
# |    n_updates        | 752      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 516      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 54596    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 1148     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 427      |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 497      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 56184    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000718 |
# |    n_updates        | 1545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 477      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 57946    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 1986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 424      |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 461      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 59590    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 2397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 422      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 445      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 61480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00175  |
# |    n_updates        | 2869     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 424      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 433      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 63160    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0328   |
# |    n_updates        | 3289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 422      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 64738    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 3684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 411      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 66406    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 4101     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 413      |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 401      |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 68032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000823 |
# |    n_updates        | 4507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 416      |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 392      |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 69792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 4947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 413      |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 384      |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 71440    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 5359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 374      |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 73634    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0526   |
# |    n_updates        | 5908     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 422      |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 367      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 75376    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 6343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 361      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 77062    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 6765     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 354      |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 78838    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00263  |
# |    n_updates        | 7209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 349      |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 80514    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00978  |
# |    n_updates        | 7628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 344      |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 82168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 8041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 426      |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 338      |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 84294    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00641  |
# |    n_updates        | 8573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 333      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 86062    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 9015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 428      |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 329      |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 87578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00652  |
# |    n_updates        | 9394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 324      |
# |    time_elapsed     | 276      |
# |    total_timesteps  | 89766    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 9941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.71     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 320      |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 91492    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00503  |
# |    n_updates        | 10372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 317      |
# |    time_elapsed     | 293      |
# |    total_timesteps  | 93084    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 10770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.7      |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 313      |
# |    time_elapsed     | 302      |
# |    total_timesteps  | 94772    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0548   |
# |    n_updates        | 11192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 310      |
# |    time_elapsed     | 310      |
# |    total_timesteps  | 96380    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00485  |
# |    n_updates        | 11594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 307      |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 98314    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00574  |
# |    n_updates        | 12078    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=27.20 +/- 8.70
# Episode length: 576.00 +/- 63.36
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 576      |
# |    mean_reward      | 27.2     |
# | rollout/            |          |
# |    exploration_rate | 0.683    |
# | time/               |          |
# |    total_timesteps  | 100000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00658  |
# |    n_updates        | 12499    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 439      |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.683    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 297      |
# |    time_elapsed     | 336      |
# |    total_timesteps  | 100084   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 12520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 440      |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 294      |
# |    time_elapsed     | 346      |
# |    total_timesteps  | 101936   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 12983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.67     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 291      |
# |    time_elapsed     | 357      |
# |    total_timesteps  | 104086   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 13521    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 289      |
# |    time_elapsed     | 366      |
# |    total_timesteps  | 105932   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00613  |
# |    n_updates        | 13982    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 286      |
# |    time_elapsed     | 377      |
# |    total_timesteps  | 108118   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 14529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 455      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 283      |
# |    time_elapsed     | 388      |
# |    total_timesteps  | 110264   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 15065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 281      |
# |    time_elapsed     | 400      |
# |    total_timesteps  | 112516   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 15628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 279      |
# |    time_elapsed     | 408      |
# |    total_timesteps  | 114066   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 16016    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 277      |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 116180   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 16544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 275      |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 117845   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 16961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 462      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 273      |
# |    time_elapsed     | 437      |
# |    total_timesteps  | 119789   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00839  |
# |    n_updates        | 17447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 271      |
# |    time_elapsed     | 448      |
# |    total_timesteps  | 121857   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0327   |
# |    n_updates        | 17964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 270      |
# |    time_elapsed     | 456      |
# |    total_timesteps  | 123491   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00999  |
# |    n_updates        | 18372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 268      |
# |    time_elapsed     | 465      |
# |    total_timesteps  | 125171   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00356  |
# |    n_updates        | 18792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 267      |
# |    time_elapsed     | 475      |
# |    total_timesteps  | 127049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 19262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 466      |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 265      |
# |    time_elapsed     | 484      |
# |    total_timesteps  | 128757   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 19689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 264      |
# |    time_elapsed     | 493      |
# |    total_timesteps  | 130401   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 20100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.581    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 262      |
# |    time_elapsed     | 503      |
# |    total_timesteps  | 132333   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 20583    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 469      |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 261      |
# |    time_elapsed     | 514      |
# |    total_timesteps  | 134483   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0336   |
# |    n_updates        | 21120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.569    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 259      |
# |    time_elapsed     | 524      |
# |    total_timesteps  | 136209   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 21552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 258      |
# |    time_elapsed     | 533      |
# |    total_timesteps  | 137997   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 21999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 467      |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 257      |
# |    time_elapsed     | 543      |
# |    total_timesteps  | 139739   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 22434    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 467      |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 256      |
# |    time_elapsed     | 552      |
# |    total_timesteps  | 141435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0388   |
# |    n_updates        | 22858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 469      |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 254      |
# |    time_elapsed     | 561      |
# |    total_timesteps  | 143289   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00668  |
# |    n_updates        | 23322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 253      |
# |    time_elapsed     | 570      |
# |    total_timesteps  | 144811   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 23702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 470      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 252      |
# |    time_elapsed     | 582      |
# |    total_timesteps  | 147109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 24277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 471      |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.528    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 251      |
# |    time_elapsed     | 592      |
# |    total_timesteps  | 148999   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 24749    |
# ----------------------------------
# Eval num_timesteps=150000, episode_reward=27.80 +/- 5.38
# Episode length: 428.40 +/- 38.42
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 428      |
# |    mean_reward      | 27.8     |
# | rollout/            |          |
# |    exploration_rate | 0.525    |
# | time/               |          |
# |    total_timesteps  | 150000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 24999    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 467      |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.522    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 247      |
# |    time_elapsed     | 608      |
# |    total_timesteps  | 150829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 25207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 470      |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 246      |
# |    time_elapsed     | 619      |
# |    total_timesteps  | 152901   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0371   |
# |    n_updates        | 25725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 245      |
# |    time_elapsed     | 628      |
# |    total_timesteps  | 154535   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.032    |
# |    n_updates        | 26133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 244      |
# |    time_elapsed     | 640      |
# |    total_timesteps  | 156719   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0775   |
# |    n_updates        | 26679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 459      |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 243      |
# |    time_elapsed     | 650      |
# |    total_timesteps  | 158425   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 27106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 467      |
# |    ep_rew_mean      | 25.2     |
# |    exploration_rate | 0.491    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 242      |
# |    time_elapsed     | 662      |
# |    total_timesteps  | 160763   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0405   |
# |    n_updates        | 27690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 241      |
# |    time_elapsed     | 670      |
# |    total_timesteps  | 162215   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 28053    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 462      |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 240      |
# |    time_elapsed     | 680      |
# |    total_timesteps  | 163999   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 28499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 458      |
# |    ep_rew_mean      | 25.3     |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 240      |
# |    time_elapsed     | 689      |
# |    total_timesteps  | 165575   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0336   |
# |    n_updates        | 28893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 456      |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.47     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 239      |
# |    time_elapsed     | 700      |
# |    total_timesteps  | 167436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0361   |
# |    n_updates        | 29358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 457      |
# |    ep_rew_mean      | 26.7     |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 238      |
# |    time_elapsed     | 710      |
# |    total_timesteps  | 169222   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0426   |
# |    n_updates        | 29805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 462      |
# |    ep_rew_mean      | 27.4     |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0288   |
# |    n_updates        | 212499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 786      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1468     |
# |    fps              | 162      |
# |    time_elapsed     | 5548     |
# |    total_timesteps  | 901906   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0518   |
# |    n_updates        | 212976   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 792      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1472     |
# |    fps              | 162      |
# |    time_elapsed     | 5568     |
# |    total_timesteps  | 905076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 213768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 798      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1476     |
# |    fps              | 162      |
# |    time_elapsed     | 5591     |
# |    total_timesteps  | 908794   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 214698   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 796      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1480     |
# |    fps              | 162      |
# |    time_elapsed     | 5609     |
# |    total_timesteps  | 911565   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0495   |
# |    n_updates        | 215391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 797      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1484     |
# |    fps              | 162      |
# |    time_elapsed     | 5628     |
# |    total_timesteps  | 914635   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0448   |
# |    n_updates        | 216158   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 797      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1488     |
# |    fps              | 162      |
# |    time_elapsed     | 5649     |
# |    total_timesteps  | 917943   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0744   |
# |    n_updates        | 216985   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 796      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1492     |
# |    fps              | 162      |
# |    time_elapsed     | 5671     |
# |    total_timesteps  | 921403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0446   |
# |    n_updates        | 217850   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 792      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1496     |
# |    fps              | 162      |
# |    time_elapsed     | 5689     |
# |    total_timesteps  | 924305   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0489   |
# |    n_updates        | 218576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 793      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 162      |
# |    time_elapsed     | 5709     |
# |    total_timesteps  | 927467   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0789   |
# |    n_updates        | 219366   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 800      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1504     |
# |    fps              | 162      |
# |    time_elapsed     | 5730     |
# |    total_timesteps  | 930781   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0726   |
# |    n_updates        | 220195   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 802      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1508     |
# |    fps              | 162      |
# |    time_elapsed     | 5751     |
# |    total_timesteps  | 934127   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0471   |
# |    n_updates        | 221031   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 799      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1512     |
# |    fps              | 162      |
# |    time_elapsed     | 5772     |
# |    total_timesteps  | 937347   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0349   |
# |    n_updates        | 221836   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 798      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1516     |
# |    fps              | 162      |
# |    time_elapsed     | 5792     |
# |    total_timesteps  | 940600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.787    |
# |    n_updates        | 222649   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 803      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1520     |
# |    fps              | 162      |
# |    time_elapsed     | 5814     |
# |    total_timesteps  | 943878   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0772   |
# |    n_updates        | 223469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 802      |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1524     |
# |    fps              | 162      |
# |    time_elapsed     | 5835     |
# |    total_timesteps  | 947144   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 224285   |
# ----------------------------------
# Eval num_timesteps=950000, episode_reward=129.00 +/- 28.37
# Episode length: 918.40 +/- 71.70
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 918      |
# |    mean_reward      | 129      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 950000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.038    |
# |    n_updates        | 224999   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 800      |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1528     |
# |    fps              | 161      |
# |    time_elapsed     | 5868     |
# |    total_timesteps  | 950382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 225095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 798      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1532     |
# |    fps              | 161      |
# |    time_elapsed     | 5890     |
# |    total_timesteps  | 953908   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.305    |
# |    n_updates        | 225976   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 800      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1536     |
# |    fps              | 161      |
# |    time_elapsed     | 5910     |
# |    total_timesteps  | 957045   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.151    |
# |    n_updates        | 226761   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 807      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1540     |
# |    fps              | 161      |
# |    time_elapsed     | 5934     |
# |    total_timesteps  | 960715   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 227678   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 808      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1544     |
# |    fps              | 161      |
# |    time_elapsed     | 5956     |
# |    total_timesteps  | 964095   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.36     |
# |    n_updates        | 228523   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 814      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1548     |
# |    fps              | 161      |
# |    time_elapsed     | 5983     |
# |    total_timesteps  | 968281   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.56     |
# |    n_updates        | 229570   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 817      |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1552     |
# |    fps              | 161      |
# |    time_elapsed     | 6006     |
# |    total_timesteps  | 971959   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0522   |
# |    n_updates        | 230489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 822      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1556     |
# |    fps              | 161      |
# |    time_elapsed     | 6027     |
# |    total_timesteps  | 975177   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0789   |
# |    n_updates        | 231294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 826      |
# |    ep_rew_mean      | 96.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 161      |
# |    time_elapsed     | 6049     |
# |    total_timesteps  | 978638   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0803   |
# |    n_updates        | 232159   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 840      |
# |    ep_rew_mean      | 98.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1564     |
# |    fps              | 161      |
# |    time_elapsed     | 6074     |
# |    total_timesteps  | 982692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0527   |
# |    n_updates        | 233172   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 840      |
# |    ep_rew_mean      | 95.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1568     |
# |    fps              | 161      |
# |    time_elapsed     | 6094     |
# |    total_timesteps  | 985856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0398   |
# |    n_updates        | 233963   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 851      |
# |    ep_rew_mean      | 95.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1572     |
# |    fps              | 161      |
# |    time_elapsed     | 6122     |
# |    total_timesteps  | 990153   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.459    |
# |    n_updates        | 235038   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 875      |
# |    ep_rew_mean      | 95.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1576     |
# |    fps              | 161      |
# |    time_elapsed     | 6160     |
# |    total_timesteps  | 996277   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0851   |
# |    n_updates        | 236569   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=131.20 +/- 58.69
# Episode length: 884.40 +/- 129.58
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 884      |
# |    mean_reward      | 131      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0885   |
# |    n_updates        | 237499   |
# ----------------------------------
# New best mean reward!

# %%
model.save("ALE-Pacman-v5-control-v4")
